# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('corporate_stress_dataset.csv')
df.head()
# Out:
#    ID  Age      Gender Marital_Status   Job_Role  Experience_Years  \
# 0   1   56  Non-Binary        Widowed  Developer                 5
# 1   2   46      Female         Single    Analyst                20
# 2   3   32      Female         Single  Developer                10
# 3   4   60      Female       Divorced    Analyst                26
# 4   5   25        Male        Married      Sales                29
#
#    Monthly_Salary_INR  Working_Hours_per_Week  Commute_Time_Hours  \
# 0           102703.08                      44                1.72
# 1           165583.91                      54                0.62
# 2            38005.39                      81                1.22
# 3            51127.36                      79                2.03
# 4           174597.45                      63                1.45
#
#    Remote_Work  ...  Work_Life_Balance Family_Support_Level Job_Satisfaction  \
# 0         True  ...                  9                    2                5
# ...

# %%
marital_status_counts = df['Marital_Status'].value_counts()
grouped_marital_status = df.groupby(['Marital_Status'])['Stress_Level'].mean()
x = grouped_marital_status.index
y = grouped_marital_status.values
plt.bar(x,y)
plt.title('Marital Status Stress Distribution')
plt.show()

# %%
gender_counts = df.loc[df['Gender']=="Non-Binary"]
gender_counts
Grouped_gender_genderbias = gender_counts.groupby(['Gender', 'Gender_Bias_Experienced']).size()
Grouped_gender_genderbias
plt.pie(Grouped_gender_genderbias, labels=Grouped_gender_genderbias.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Gender Bias Experience Distribution')
plt.show()

# %%
bins = [-1, 3, 7, 10]  
labels = ["Low", "Medium", "High"]


df["Stress Category"] = pd.cut(df["Stress_Level"], bins=bins, labels=labels)


result = df.groupby(["Marital_Status", "Stress Category"]).size().reset_index(name="Count")
result
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_34424\2726804252.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   result = df.groupby(["Marital_Status", "Stress Category"]).size().reset_index(name="Count")
#    Marital_Status Stress Category  Count
# 0        Divorced             Low   4535
# 1        Divorced          Medium   4570
# 2        Divorced            High   3410
# 3         Married             Low   4494
# 4         Married          Medium   4545
# 5         Married            High   3460
# 6          Single             Low   4566
# 7          Single          Medium   4605
# 8          Single            High   3398
# 9         Widowed             Low   4529
# 10        Widowed          Medium   4524
# 11        Widowed            High   3364
